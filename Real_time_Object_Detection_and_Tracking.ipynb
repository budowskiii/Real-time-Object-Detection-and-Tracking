# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.6/615.6 kB 9.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/YoloV8_custom
# Out:
# /content/drive/MyDrive/YoloV8_custom

# %%
# !ls
# Out:
# classes.txt  data_custom.yaml  train  val

# %%
# !yolo task = detect mode = train epochs=100 data=data_custom.yaml model=yolov8m.pt imgsz=640
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=best_2.pt show = True conf =0.5 source = test_file_2.jpeg
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/YoloV8_custom/test_file_2.jpeg: 384x640 1 wajahat, 1 painting, 62.4ms
# Speed: 1.8ms preprocess, 62.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=best_2.pt show = True conf =0.5 source = 20231001_083449.mp4 save_txt = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/206) /content/drive/MyDrive/YoloV8_custom/20231001_083449.mp4: 384x640 1 wajahat, 1 painting, 89.4ms
# video 1/1 (2/206) /content/drive/MyDrive/YoloV8_custom/20231001_083449.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# video 1/1 (3/206) /content/drive/MyDrive/YoloV8_custom/20231001_083449.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# video 1/1 (4/206) /content/drive/MyDrive/YoloV8_custom/20231001_083449.mp4: 384x640 1 wajahat, 1 painting, 25.9ms
# video 1/1 (5/206) /content/drive/MyDrive/YoloV8_custom/20231001_083449.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# video 1/1 (6/206) /content/drive/MyDrive/YoloV8_custom/20231001_083449.mp4: 384x640 1 wajahat, 1 painting, 25.9ms
# ...

# %%
# !yolo task=detect mode=predict model=best_2.pt show = True conf =0.5 source = 20231001_083501.mp4 save_txt = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/254) /content/drive/MyDrive/YoloV8_custom/20231001_083501.mp4: 384x640 1 wajahat, 1 painting, 102.6ms
# video 1/1 (2/254) /content/drive/MyDrive/YoloV8_custom/20231001_083501.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# video 1/1 (3/254) /content/drive/MyDrive/YoloV8_custom/20231001_083501.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# video 1/1 (4/254) /content/drive/MyDrive/YoloV8_custom/20231001_083501.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# video 1/1 (5/254) /content/drive/MyDrive/YoloV8_custom/20231001_083501.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# video 1/1 (6/254) /content/drive/MyDrive/YoloV8_custom/20231001_083501.mp4: 384x640 1 wajahat, 1 painting, 25.8ms
# ...

# %%
# !yolo task=detect mode=predict model=best_2.pt show = True conf =0.5 source = 20231001_083513.mp4 save_txt = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/188) /content/drive/MyDrive/YoloV8_custom/20231001_083513.mp4: 384x640 1 wajahat, 1 painting, 1 earbuds, 102.0ms
# video 1/1 (2/188) /content/drive/MyDrive/YoloV8_custom/20231001_083513.mp4: 384x640 1 wajahat, 1 painting, 1 earbuds, 25.8ms
# video 1/1 (3/188) /content/drive/MyDrive/YoloV8_custom/20231001_083513.mp4: 384x640 1 wajahat, 1 painting, 1 earbuds, 25.8ms
# video 1/1 (4/188) /content/drive/MyDrive/YoloV8_custom/20231001_083513.mp4: 384x640 1 wajahat, 1 painting, 1 earbuds, 25.8ms
# video 1/1 (5/188) /content/drive/MyDrive/YoloV8_custom/20231001_083513.mp4: 384x640 1 wajahat, 1 painting, 1 earbuds, 25.8ms
# ...
